# %%
import requests
from bs4 import BeautifulSoup


url = 'https://varlamov.ru/3194037.html'
text = requests.get(url).text
text_good = BeautifulSoup(text, "html.parser")
print(text_good.find(itemprop="text").text)
# Out:
#  Фото: Николай Хижняк / РИА «Новости» Первомайский районный суд Краснодара отменил наказание рэперу Хаски (Дмитрию Кузнецову) по статье о мелком хулиганстве. Суд только что удовлетворил заявление защитников репера Хаски (Дмитрия Кузнецова) и прекратил исполнение наказания в виде административного ареста на 12 суток. Постановление подлежит немедленному исполнению. Едем в спецприемник за Дмитрием. #свободухаски #замузыкантамипришли #ябудупетьсвоюмузыку Адвокат Алексей Аванесян В Краснодаре 21 ноября из-за того, что концертная площадка отменила выступление Хаски после предостережения прокуратуры, рэпер решил прочитать свои песни на улице. Музыканта задержали, когда тот залез на автомобиль и начал исполнять свою песню толпе. В полиции на рэпера составили протоколы об организации массового пребывания граждан в общественных местах (часть 1 статьи 20.2.2 КоАП), мелком хулиганстве, сопряженном с неповиновением законному требованию представителя власти (часть 2 статьи 20.1 КоАП), и об отказе 
# ...

# %%
print(text_good)
# Out:
# <!DOCTYPE doctype html>
# <html class="html-adaptive" id="no-js"><head><meta charset="utf-8"/><title>Суд отменил 12 суток ареста Хаски – Новости Варламов.ру</title><meta content="Блог Ильи Варламова" name="description"/><meta content="text/html;charset=utf-8" http-equiv="Content-Type">
# <link href="https://l-files.livejournal.net/userhead/982?v=1353584500?v=291.2" rel="icon" type="image/gif"/>
# <link href="" rel="stylesheet" type="text/css">
# <link href="https://varlamov.ru/data/foaf" rel="meta" title="FOAF" type="application/rdf+xml"/>
# <meta content="foaf:mbox_sha1sum bce50a7a16dfac773aace51068f21393fbf6d379" name="foaf:maker">
# <link href="https://l-stat.livejournal.net/??schemius_v4/header_v5.css,schemius_v4/header-journal.css,medius/scheme/components.css?v=1544009121" rel="stylesheet" type="text/css"/>
# ...
